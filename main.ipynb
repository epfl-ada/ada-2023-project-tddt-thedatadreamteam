# %% [markdown]
# # Imports

# %%
import os
import re
import pandas as pd
from scipy.special import softmax

# %% [markdown]
# # Data loading

# %%
df_categories = pd.read_csv(
    os.path.join("Data", "wikispeedia_paths-and-graph", "categories.tsv"),
    sep="\t",
    comment='#',
    skip_blank_lines=True,
    header=None,
    names=["name", "category"]
)

df_categories.head()
# Out:
#                                name  \
# 0  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 1  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 2                        %C3%85land
# 3                        %C3%85land
# 4                %C3%89douard_Manet
#
#                                             category
# 0  subject.History.British_History.British_Histor...
# 1                  subject.People.Historical_figures
# 2                                  subject.Countries
# 3  subject.Geography.European_Geography.European_...
# 4                             subject.People.Artists

# %%
df_paths_finished = pd.read_csv(
    os.path.join("Data", "wikispeedia_paths-and-graph", "paths_finished.tsv"),
    sep="\t",
    comment='#',
    skip_blank_lines=True,
    header=None,
    index_col=False,
    names=["hashedIpAddress", "timestamp", "durationInSec", "path", "rating"]
)

df_paths_finished["start"] = df_paths_finished.path.apply(lambda x: x.split(";")[0])
df_paths_finished["target"] = df_paths_finished.path.apply(lambda x: x.split(";")[-1])

df_paths_finished.head()
# Out:
#     hashedIpAddress   timestamp  durationInSec  \
# 0  6a3701d319fc3754  1297740409            166
# 1  3824310e536af032  1344753412             88
# 2  415612e93584d30e  1349298640            138
# 3  64dd5cd342e3780c  1265613925             37
# 4  015245d773376aab  1366730828            175
#
#                                                 path  rating         start  \
# 0  14th_century;15th_century;16th_century;Pacific...     NaN  14th_century
# 1  14th_century;Europe;Africa;Atlantic_slave_trad...     3.0  14th_century
# 2  14th_century;Niger;Nigeria;British_Empire;Slav...     NaN  14th_century
# 3     14th_century;Renaissance;Ancient_Greece;Greece     NaN  14th_century
# 4  14th_century;Italy;Roman_Catholic_Church;HIV;R...     3.0  14th_century
#
#                 target
# 0  African_slave_trade
# 1  African_slave_trade
# 2  African_slave_trade
# 3               Greece
# 4      John_F._Kennedy

# %%
df_paths_unfinished = pd.read_csv(
    os.path.join("Data", "wikispeedia_paths-and-graph", "paths_unfinished.tsv"),
    sep="\t",
    comment='#',
    skip_blank_lines=True,
    header=None,
    index_col=False,
    names=["hashedIpAddress", "timestamp", "durationInSec", "path", "target", "type"]
)

df_paths_unfinished["start"] = df_paths_unfinished.path.apply(lambda x: x.split(";")[0])

df_paths_unfinished.head()
# Out:
#     hashedIpAddress   timestamp  durationInSec  \
# 0  2426091a53125110  1297054935           1804
# 1  26141fd878806294  1297055651           1805
# 2  2b015fb8181c48f2  1297090819           1818
# 3  53a53bc244e08a6a  1297094761             49
# 4  53a53bc244e08a6a  1297099105           1808
#
#                                    path            target     type  \
# 0                        Obi-Wan_Kenobi         Microsoft  timeout
# 1                         Julius_Caesar           Caracas  timeout
# 2  Malawi;Democracy;Alexander_the_Great     First_Crusade  timeout
# 3                              Paraguay  Mount_St._Helens  restart
# 4                      Paraguay;Bolivia  Mount_St._Helens  timeout
#
#             start
# 0  Obi-Wan_Kenobi
# 1   Julius_Caesar
# 2          Malawi
# 3        Paraguay
# 4        Paraguay

# %%
df_links = pd.read_csv(
    os.path.join("Data", "links_with_order.tsv"),
    delimiter="\t",
).sort_values(by="order")

df_links.head()
# Out:
#                                 linkSource           linkTarget  order
# 60904                              Khazars    History_of_Russia    1.0
# 70072                            Marseille    List_of_countries    1.0
# 70094                     Marshall_Islands     English_language    1.0
# 31458  Domestic_AC_power_plugs_and_sockets  Alternating_current    1.0
# 4285                       Akkadian_Empire          Mesopotamia    1.0

# %%
df_page_rank = pd.read_csv(os.path.join("Data", "page_rank.csv")).sort_values(by="PageRank", ascending=False)

df_page_rank.head()
# Out:
#                      Article  PageRank
# 0              United_States  0.014263
# 1             United_Kingdom  0.007679
# 2  Scientific_classification  0.007209
# 3                     Europe  0.007043
# 4                    England  0.006815

# %% [markdown]
# # Continent categories

# %%
categories = df_categories.category.unique()

subcategories = {}
init_key_words = {
    "Europe": [
        "europe",
        "britain",
        "british"
    ],
    "North America": [
        "north_americ",
        "usa",
        "canadian",
    ],
    "Asia": [
        "asia",
    ],
    "Africa": [
        "africa"
    ],
    "South America": [
        "south_americ"
    ],
    "Australia": [
        "australasia"
    ],
    "Antarctica": [
        "antarctica"
    ],
    "Middle East": [
        "middle_east"
    ],
}

for category in categories:

    found = False
    for key, values in init_key_words.items():
        for value in values:
            if re.search(f"[\._]{value}", category.lower()):
                if key not in subcategories:
                    subcategories[key] = set()
                subcategories[key].add(category)

                found = True
                break
        if found:
            break

# %%
key_words = {}

for name in df_categories.name.unique():
    name_category = df_categories[df_categories.name == name].category.values
    name = name.lower()

    found = False
    for key, values in init_key_words.items():
        for value in values:
            for category in name_category:
                if re.search(f"[\._]{value}", category.lower()):
                    if key not in key_words:
                        key_words[key] = []
                    key_words[key].append(name)
                    subcategories[key].add(category)

                    found = True
                    break
            if found:
                break
        if found:
            break

# %%
print("Categories and their Subcategories:")
for key in sorted(subcategories, key=lambda x: len(subcategories[x]), reverse=True):
    print(f"Category: {key}, Subcategories count: {len(subcategories[key])}")
    for value in subcategories[key]:
        print("--->", value)
    print()
# Out:
# Categories and their Subcategories:
# Category: Europe, Subcategories count: 9
# ---> subject.History.British_History.British_History_1500_and_before_including_Roman_Britain
# ---> subject.History.British_History.British_History_17501900
# ---> subject.History.British_History.British_History_15001750
# ---> subject.People.Monarchs_of_Great_Britain
# ---> subject.Geography.European_Geography.European_Countries
# ---> subject.History.British_History
# ---> subject.Geography.European_Geography
# ---> subject.History.British_History.British_History_Post_1900
# ---> subject.Geography.Geography_of_Great_Britain
#
# Category: North America, Subcategories count: 3
# ---> subject.History.North_American_History
# ---> subject.People.USA_Presidents
# ---> subject.Geography.North_American_Geography
#
# Category: Middle East, Subcategories count: 2
# ---> subject.Geography.Geography_of_the_Middle_East.Middle_Eastern_Countries
# ---> subject.Geography.Geography_of_the_Middle_East
#
# Category: Africa, Subcategories count: 2
# ---> subject.Geography.African_Geography.African_Countries
# ---> subject.Geography.African_Geography
#
# Category: Asia, Subcategories count: 2
# ---> subject.Geography.Geography_of_Asia.Asian_Countries
# ---> subject.Geography.Geography_of_Asia
#
# Category: South America, Subcategories count: 2
# ---> subject.Geography.Central_and_South_American_Geography.Central_and_South_American_Countries
# ---> subject.Geography.Central_and_South_American_Geography
#
# Category: Australia, Subcategories count: 1
# ---> subject.Geography.Geography_of_Oceania_Australasia
#
# Category: Antarctica, Subcategories count: 1
# ---> subject.Geography.Antarctica

# %%
print("Number of Categories Key Words:")
for key, values in key_words.items():
    print(f"Category: {key : >15}, Key words count: {len(values)}")
# Out:
# Number of Categories Key Words:
# Category:          Europe, Key words count: 421
# Category:     Middle East, Key words count: 32
# Category:          Africa, Key words count: 137
# Category:            Asia, Key words count: 106
# Category:   North America, Key words count: 162
# Category:       Australia, Key words count: 57
# Category:   South America, Key words count: 83
# Category:      Antarctica, Key words count: 8

# %%
all_categories = []
for values in subcategories.values():
    all_categories.extend(values)

df_rest = df_categories[~df_categories.category.isin(all_categories)]

article_labeled = {}
for key, values in subcategories.items():
    for value in values:
        for name in df_categories[df_categories.category == value].name.unique():
            if name in article_labeled:
                continue
            article_labeled[name] = key

for key, values in init_key_words.items():
    for value in values:
        for name in df_rest[df_rest.name.str.lower().str.contains(value)].name.unique():
            if name in article_labeled:
                continue
            article_labeled[name] = key

for key, values in key_words.items():
    for value in values:
        for name in df_rest[df_rest.name.str.lower().str.contains(value)].name.unique():
            if name in article_labeled:
                continue
            article_labeled[name] = key

print(f"Number of articles with assigned continent category: {len(article_labeled)}")
# Out:
# Number of articles with assigned continent category: 1318

# %% [markdown]
# ## Number of articles per each continent group

# %%
line_size = 33
col1_size = 13

df_article_labeled = pd.DataFrame(article_labeled.items(), columns=["name", "category"])

print("-" * line_size)
print(f"| {'Continent' : <{col1_size}} | Aricles count |")
print("-" * line_size)
for name, count in df_article_labeled.category.value_counts().items():
    print(f"| {name : <{col1_size}} | {count : <{len('Aricles count')}} |")
print("-" * line_size)
# Out:
# ---------------------------------
# | Continent     | Aricles count |
# ---------------------------------
# | Europe        | 568           |
# | North America | 211           |
# | Africa        | 167           |
# | Asia          | 147           |
# | South America | 93            |
# | Australia     | 68            |
# | Middle East   | 56            |
# | Antarctica    | 8             |
# ---------------------------------

# %%
line_size = 33
col1_size = 13

map_ = {
    "Europe": "Europe",
    "North America": "North America",
    "Asia": "Other",
    "Africa": "Other",
    "South America": "Other",
    "Australia": "Other",
    "Antarctica": "Other",
    "Middle East": "Other",
}



df_article_labeled = pd.DataFrame(article_labeled.items(), columns=["name", "category"])
df_article_labeled["categories_grouped"] = df_article_labeled.category.map(map_)

print("-" * line_size)
print(f"| {'Continent' : <{col1_size}} | Aricles count |")
print("-" * line_size)
for name, count in df_article_labeled.categories_grouped.value_counts().items():
    print(f"| {name : <{col1_size}} | {count : <{len('Aricles count')}} |")
print("-" * line_size)
# Out:
# ---------------------------------
# | Continent     | Aricles count |
# ---------------------------------
# | Europe        | 568           |
# | Other         | 539           |
# | North America | 211           |
# ---------------------------------

# %% [markdown]
# ## Number of paths with start/target article labeled with continent category

# %%
line_size = 41
col1_size = 13
col2_size = 8
col3_size = 10

print("-" * line_size)
print(f"| {'Start' : <{col1_size}} | {'Finished' : <{col2_size}} | {'Unfinished' : <{col3_size}} |")
print("-" * line_size)
for key in subcategories.keys():
    names = df_article_labeled[df_article_labeled.category == key].name.values
    print(f"| {key : <{col1_size}} | {len(df_paths_finished[df_paths_finished.start.isin(names)]) : <{col2_size}} | {len(df_paths_unfinished[df_paths_unfinished.start.isin(names)]) : <{col3_size}} |")

print("-" * line_size)
print(f"| {'Target' : <{col1_size}} | {'Finished' : <{col2_size}} | {'Unfinished' : <{col3_size}} |")
print("-" * line_size)
for key in subcategories.keys():
    names = df_article_labeled[df_article_labeled.category == key].name.values
    print(f"| {key : <{col1_size}} | {len(df_paths_finished[df_paths_finished.target.isin(names)]) : <{col2_size}} | {len(df_paths_unfinished[df_paths_unfinished.target.isin(names)]) : <{col3_size}} |")
print("-" * line_size)
# Out:
# -----------------------------------------
# | Start         | Finished | Unfinished |
# -----------------------------------------
# | Europe        | 5120     | 2325       |
# | Middle East   | 584      | 240        |
# | Africa        | 1562     | 611        |
# | Asia          | 1464     | 658        |
# | North America | 1920     | 973        |
# | Australia     | 567      | 266        |
# | South America | 958      | 460        |
# | Antarctica    | 73       | 24         |
# -----------------------------------------
# | Target        | Finished | Unfinished |
# -----------------------------------------
# | Europe        | 6512     | 2398       |
# | Middle East   | 872      | 153        |
# | Africa        | 1731     | 398        |
# | Asia          | 1859     | 580        |
# | North America | 2693     | 799        |
# | Australia     | 490      | 211        |
# | South America | 1165     | 320        |
# | Antarctica    | 69       | 30         |
# -----------------------------------------

# %%
line_size = 41
col1_size = 13
col2_size = 8
col3_size = 10

print("-" * line_size)
print(f"| {'Start' : <{col1_size}} | {'Finished' : <{col2_size}} | {'Unfinished' : <{col3_size}} |")
print("-" * line_size)
for key in df_article_labeled.categories_grouped.unique():
    names = df_article_labeled[df_article_labeled.categories_grouped == key].name.values
    print(f"| {key : <{col1_size}} | {len(df_paths_finished[df_paths_finished.start.isin(names)]) : <{col2_size}} | {len(df_paths_unfinished[df_paths_unfinished.start.isin(names)]) : <{col3_size}} |")

print("-" * line_size)
print(f"| {'Target' : <{col1_size}} | {'Finished' : <{col2_size}} | {'Unfinished' : <{col3_size}} |")
print("-" * line_size)
for key in df_article_labeled.categories_grouped.unique():
    names = df_article_labeled[df_article_labeled.categories_grouped == key].name.values
    print(f"| {key : <{col1_size}} | {len(df_paths_finished[df_paths_finished.target.isin(names)]) : <{col2_size}} | {len(df_paths_unfinished[df_paths_unfinished.target.isin(names)]) : <{col3_size}} |")
print("-" * line_size)
# Out:
# -----------------------------------------
# | Start         | Finished | Unfinished |
# -----------------------------------------
# | Europe        | 5120     | 2325       |
# | Other         | 5208     | 2259       |
# | North America | 1920     | 973        |
# -----------------------------------------
# | Target        | Finished | Unfinished |
# -----------------------------------------
# | Europe        | 6512     | 2398       |
# | Other         | 6186     | 1692       |
# | North America | 2693     | 799        |
# -----------------------------------------

# %% [markdown]
# # Continent category assignment based on weigted combination of outgoing links
#
# The link weight is the ```1/i``` where ```i``` is the order of link position on the article page.

# %%
def get_category_by_links(article_name, df_links, article_labeled):
    links = df_links[df_links.linkSource == article_name].linkTarget.values
    counter = {}
    for link_index, link in enumerate(links, 1):
        if link in article_labeled.keys():
            continent = article_labeled[link]
            if continent in counter.keys():
                counter[continent] += 1.0 / link_index
            else:
                counter[continent] = 1.0 / link_index

    if len(counter.values()) == 0:
        return "Unknown"

    softmax_values = softmax(list(counter.values()))
    softmax_dict = dict(zip(counter.keys(), softmax_values))

    return max(softmax_dict, key=lambda k: softmax_dict[k])

# %%
print("Articles with continent category assigned based on outgoing links:")
for article in df_categories[df_categories.category.str.startswith("subject.People")].name.unique():
    print(f"{article :.<50}{get_category_by_links(article, df_links, article_labeled)}")
# Out:
# Articles with continent category assigned based on outgoing links:
# %C3%81ed%C3%A1n_mac_Gabr%C3%A1in..................Europe
# %C3%89douard_Manet................................Europe
# %C3%93engus_I_of_the_Picts........................Europe
# A._E._J._Collins..................................Europe
# Abbas_I_of_Persia.................................Europe
# Abel_Tasman.......................................Australia
# Abraham_Goldfaden.................................Europe
# Abraham_Lincoln...................................North America
# Adam_Smith........................................Europe
# Adi_Shankara......................................Asia
# Adolf_Hitler......................................Europe
# Adriaen_van_der_Donck.............................North America
# Agamemnon.........................................Europe
# Akbar.............................................Asia
# Akhenaten.........................................Africa
# Akira_Kurosawa....................................Asia
# Alan_Turing.......................................Europe
# Albert_Einstein...................................Europe
# Alberto_Santos-Dumont.............................South America
# Albrecht_D%C3%BCrer...............................Europe
# Albrecht_Rodenbach................................Europe
# Alcibiades........................................Europe
# Aleksandr_Pushkin.................................Europe
# Aleksandr_Vasilevsky..............................Europe
# Aleksey_Arakcheyev................................Europe
# Alexander_Graham_Bell.............................Europe
# Alexander_Hamilton................................North America
# Alexander_the_Great...............................Europe
# Alfred_Hitchcock..................................Europe
# Alfred_Nobel......................................Europe
# Alfred_the_Great..................................Europe
# Amda_Seyon_I......................................Africa
# Andr%C3%A9s_Nocioni...............................South America
# Andrew_Carnegie...................................Europe
# Andrew_Dickson_White..............................North America
# Andrew_Gonzalez...................................Asia
# Andrew_Jackson....................................North America
# Andrew_Johnson....................................North America
# Andrew_Robinson...................................North America
# Andy_Warhol.......................................North America
# Anne_Frank........................................Europe
# Anne_of_Great_Britain.............................Europe
# Annibale_Bugnini..................................Middle East
# Anthony_van_Dyck..................................Europe
# Antoine_Lavoisier.................................Europe
# Anton%C3%ADn_Dvo%C5%99%C3%A1k.....................Europe
# Anton_Alexander_von_Werner........................Europe
# Antonio_Vivaldi...................................Europe
# Archbishop_of_Canterbury..........................Europe
# Archimedes........................................Europe
# Ariel_Sharon......................................Middle East
# Aristotle.........................................Europe
# Armand_Jean_du_Plessis%2C_Cardinal_Richelieu......Europe
# Armia_Krajowa.....................................Europe
# Arnold_Schwarzenegger.............................Europe
# Arthur_Ernest_Percival............................Europe
# Arthur_Sullivan...................................Europe
# Arthur_Upfield....................................Australia
# Arthur_Wellesley%2C_1st_Duke_of_Wellington........Europe
# Athanasius_Kircher................................Europe
# Attalus_I.........................................Europe
# Attila_the_Hun....................................Europe
# Augusta%2C_Lady_Gregory...........................Europe
# Auguste_Rodin.....................................Europe
# Augustine_of_Hippo................................Middle East
# Augustus..........................................Europe
# Ayaan_Hirsi_Ali...................................Africa
# Aymer_de_Valence%2C_2nd_Earl_of_Pembroke..........Europe
# Babe_Ruth.........................................North America
# Babur.............................................Asia
# Banksy............................................Europe
# Barack_Obama......................................North America
# Barbara_McClintock................................North America
# Baruch_Spinoza....................................Europe
# Ben_Jonson........................................Europe
# Benito_Mussolini..................................Europe
# Benjamin_Britten..................................Europe
# Benjamin_Disraeli%2C_1st_Earl_of_Beaconsfield.....Europe
# Benjamin_Franklin.................................North America
# Benjamin_Harrison.................................North America
# Bernard_Hinault...................................Europe
# Bertrand_Russell..................................Europe
# Bette_Davis.......................................Europe
# Bill_Clinton......................................North America
# Bill_Gates........................................Europe
# Billie_Holiday....................................North America
# Bj%C3%B6rn_Borg...................................Europe
# Blaise_Pascal.....................................Europe
# Bob_Dylan.........................................North America
# Bob_Marley........................................North America
# Boris_Becker......................................Europe
# Boudica...........................................Europe
# Boyle_Roche.......................................Europe
# Brandon_Routh.....................................North America
# Breaker_Morant....................................Europe
# Brian_Close.......................................Europe
# Britney_Spears....................................North America
# Brothers_Grimm....................................Europe
# Bruce_Lee.........................................North America
# Bruce_Springsteen.................................North America
# Buckminster_Fuller................................North America
# Buddha............................................Asia
# C%C3%A6dmon.......................................Europe
# C._S._Lewis.......................................Europe
# Cai_Lun...........................................Asia
# Calvin_Coolidge...................................North America
# Canaletto.........................................Europe
# Canute_the_Great..................................Europe
# Caratacus.........................................Europe
# Caravaggio........................................Europe
# Carl_Friedrich_Gauss..............................Europe
# Carl_G._Fisher....................................North America
# Carl_Jung.........................................Europe
# Carl_Lewis........................................North America
# Carl_Sagan........................................North America
# Carolus_Linnaeus..................................Europe
# Cat_Stevens.......................................Europe
# Catherine_II_of_Russia............................Europe
# Celine_Dion.......................................North America
# Charlemagne.......................................Europe
# Charles_Babbage...................................Europe
# Charles_Darwin....................................Europe
# Charles_Dickens...................................Europe
# Charles_Etienne_Brasseur_de_Bourbourg.............Europe
# Charles_II_of_England.............................Europe
# Charles_I_of_England..............................Europe
# Charles_Sumner....................................North America
# Charles_V%2C_Holy_Roman_Emperor...................Europe
# Charlie_Chaplin...................................Europe
# Che_Guevara.......................................South America
# Chester_A._Arthur.................................North America
# Chris_Evert.......................................North America
# Christian_Bale....................................Europe
# Christina_Aguilera................................North America
# Christopher_Columbus..............................Europe
# Christopher_Wren..................................Europe
# Claude_L%C3%A9vi-Strauss..........................Europe
# Claude_Monet......................................Europe
# Claudius..........................................Europe
# Cleopatra_VII.....................................Africa
# Cleopatra_VII_of_Egypt............................Africa
# Colley_Cibber.....................................Europe
# Columba...........................................Europe
# Condoleezza_Rice..................................North America
# Confucius.........................................Asia
# Constantine_I.....................................Europe
# Cyril_Clarke......................................Europe
# Cyrus_K._Holliday.................................North America
# Cyrus_the_Great...................................Middle East
# Daley_Thompson....................................Europe
# Damon_Hill........................................Europe
# Daniel_Day-Lewis..................................Europe
# Daniel_Ellsberg...................................Asia
# Dante_Alighieri...................................Europe
# David_Attenborough................................Europe
# David_Beckham.....................................Europe
# David_Blanchflower................................Europe
# David_Cameron.....................................Europe
# David_Helvarg.....................................North America
# David_Heymann.....................................North America
# David_Hilbert.....................................Europe
# David_Hume........................................Europe
# David_Livingstone.................................Europe
# Demosthenes.......................................Europe
# Denis_Law.........................................Europe
# Dennis_Ritchie....................................Unknown
# Desmond_Tutu......................................Africa
# Diane_Keaton......................................North America
# Diego_Maradona....................................South America
# Diego_Vel%C3%A1zquez..............................Europe
# Dmitri_Mendeleev..................................Europe
# Donald_Bradman....................................Australia
# Donald_Knuth......................................Europe
# Douglas_Adams.....................................Europe
# Dr._Seuss.........................................North America
# Du_Fu.............................................Europe
# Dwight_D._Eisenhower..............................North America
# E._E._Cummings....................................North America
# E._P._Wigner......................................Europe
# Earl_of_Shaftesbury...............................Europe
# Edgar_Allan_Poe...................................North America
# Edmond_Halley.....................................Europe
# Edmund_Burke......................................Europe
# Edmund_Hillary....................................Australia
# Edward_II_of_England..............................Europe
# Edward_IV_of_England..............................Europe
# Edward_I_of_England...............................Europe
# Edward_Jenner.....................................Europe
# Edward_Teller.....................................Europe
# Edward_VIII_of_the_United_Kingdom.................Europe
# Edward_VII_of_the_United_Kingdom..................Europe
# Edward_the_Confessor..............................Europe
# Edwin_of_Northumbria..............................Europe
# Eilmer_of_Malmesbury..............................Europe
# El_Lissitzky......................................Europe
# Elagabalus........................................Europe
# Elias_Ashmole.....................................Europe
# Elizabeth_Fry.....................................Europe
# Elizabeth_II_of_the_United_Kingdom................Europe
# Elizabeth_I_of_England............................Europe
# Elvis_Presley.....................................North America
# Emanuel_Swedenborg................................Europe
# Emma_Roberts......................................North America
# Epaminondas.......................................Europe
# Eric_Clapton......................................Europe
# Ernest_Hemingway..................................Europe
# Ernest_Rutherford.................................Europe
# Euclid............................................Europe
# Eva_Per%C3%B3n....................................South America
# Evan_Rachel_Wood..................................North America
# Ezra_Pound........................................North America
# Fanny_Blankers-Koen...............................Europe
# Felice_Beato......................................Asia
# Felix_Mendelssohn.................................Europe
# Ferdinand_Magellan................................Europe
# Fidel_Castro......................................South America
# Florence_Nightingale..............................Europe
# Floyd_Mayweather_Jr...............................North America
# Fr%C3%A9d%C3%A9ric_Chopin.........................Europe
# Frances_Oldham_Kelsey.............................North America
# Francis_Bacon.....................................Europe
# Francis_Crick.....................................North America
# Francis_Drake.....................................Europe
# Francis_of_Assisi.................................Europe
# Francisco_Goya....................................Europe
# Franklin_B._Gowen.................................Europe
# Franklin_D._Roosevelt.............................North America
# Franklin_Pierce...................................North America
# Franz_Kafka.......................................Europe
# Franz_Schubert....................................Europe
# Frederick_Douglass................................Europe
# Frederick_Hamilton-Temple-Blackwood%2C_1st_Marquess_of_Dufferin_and_AvaEurope
# Frederick_II%2C_Holy_Roman_Emperor................Europe
# Frederick_II_of_Prussia...........................Europe
# Friedrich_Nietzsche...............................Europe
# Fyodor_Dostoevsky.................................Europe
# Galileo_Galilei...................................Europe
# Gautama_Buddha....................................Asia
# Genghis_Khan......................................Asia
# Georg_Cantor......................................Europe
# Georg_Forster.....................................Europe
# Georg_von_Boeselager..............................Europe
# George_Byron%2C_6th_Baron_Byron...................Europe
# George_Eliot......................................Europe
# George_Fox........................................Europe
# George_H._W._Bush.................................North America
# George_Herbert....................................Europe
# George_III_of_the_United_Kingdom..................Europe
# George_II_of_Great_Britain........................Europe
# George_IV_of_the_United_Kingdom...................Europe
# George_I_of_Great_Britain.........................Europe
# George_Thomas_Coker...............................North America
# George_VI_of_the_United_Kingdom...................Europe
# George_V_of_the_United_Kingdom....................Europe
# George_W._Bush....................................North America
# George_Washington.................................North America
# Gerald_Durrell....................................Europe
# Gerald_Ford.......................................North America
# Gilles_Villeneuve.................................North America
# Giuseppe_Verdi....................................Europe
# Glynn_Lunney......................................North America
# Gordon_Brown......................................Europe
# Gordon_Griffith...................................North America
# Gottfried_Leibniz.................................Europe
# Greg_LeMond.......................................North America
# Gregor_Mendel.....................................Europe
# Grover_Cleveland..................................North America
# Guglielmo_Marconi.................................Europe
# Gustav_Holst......................................Europe
# Gustavus_Franklin_Swift...........................North America
# H.D...............................................Europe
# Haji_Mohammad_Suharto.............................Asia
# Hannibal_Barca....................................Europe
# Harold_Macmillan..................................Europe
# Harold_Wilson.....................................Europe
# Harry_S._Truman...................................North America
# Hasekura_Tsunenaga................................Europe
# Hatshepsut........................................Africa
# Helen.............................................Europe
# Helen_Gandy.......................................North America
# Henri_Matisse.....................................Europe
# Henrik_Ibsen......................................Europe
# Henry_David_Thoreau...............................North America
# Henry_Fonda.......................................North America
# Henry_Ford........................................North America
# Henry_H._Rogers...................................North America
# Henry_III_of_England..............................Europe
# Henry_II_of_England...............................Europe
# Henry_IV_of_England...............................Europe
# Henry_I_of_England................................Europe
# Henry_James.......................................North America
# Henry_Moore.......................................Europe
# Henry_Morrison_Flagler............................North America
# Henry_Morton_Stanley..............................Africa
# Henry_Purcell.....................................Europe
# Henry_Rollins.....................................North America
# Henry_VIII_of_England.............................Europe
# Henry_VII_of_England..............................Europe
# Henry_VI_of_England...............................Europe
# Henry_V_of_England................................Europe
# Henry_Wood_%28conductor%29........................Europe
# Heraclius.........................................Middle East
# Herbert_Hoover....................................North America
# Hermann_Maier.....................................Europe
# Hern%C3%A1n_Cort%C3%A9s...........................Europe
# Hilda_of_Whitby...................................Middle East
# Hippocrates.......................................Europe
# Hiroh_Kikai.......................................Asia
# Hirohito..........................................Asia
# Ho_Chi_Minh.......................................Asia
# Homer.............................................Europe
# Horatio_Nelson%2C_1st_Viscount_Nelson.............Europe
# Hugo_Wolf.........................................Europe
# Humbert_Roque_Versace.............................Asia
# Humphry_Davy......................................Europe
# Husein_Grada%C5%A1%C4%8Devi%C4%87.................Europe
# Ibn_Battuta.......................................Asia
# Idit_Harel_Caperton...............................Middle East
# Igor_Stravinsky...................................North America
# Ike_Altgens.......................................North America
# Immanuel_Kant.....................................Europe
# Indira_Gandhi.....................................Asia
# Isaac.............................................Africa
# Isaac_Asimov......................................North America
# Isaac_Brock.......................................Europe
# Isaac_Newton......................................Europe
# Isambard_Kingdom_Brunel...........................Europe
# Ivan_IV_of_Russia.................................Europe
# J%C3%B3zef_Pi%C5%82sudski.........................Europe
# J._J._Thomson.....................................Europe
# J._K._Rowling.....................................Europe
# J._M._W._Turner...................................Europe
# J._R._R._Tolkien..................................Europe
# Jack_Kerouac......................................North America
# Jackie_Robinson...................................Europe
# Jacob_Riis........................................Europe
# Jacques-Louis_David...............................Europe
# Jacques_Cartier...................................North America
# Jake_Gyllenhaal...................................North America
# James_Buchanan....................................North America
# James_Callaghan...................................Europe
# James_Clerk_Maxwell...............................Europe
# James_Cook........................................Europe
# James_D._Watson...................................North America
# James_Garfield....................................North America
# James_II_of_England...............................Europe
# James_I_of_England................................Europe
# James_Joyce.......................................Europe
# James_K._Polk.....................................North America
# James_Lovelock....................................Europe
# James_Monroe......................................North America
# James_Stewart_%28actor%29.........................North America
# James_T._Aubrey%2C_Jr.............................North America
# James_Watt........................................Europe
# Jane_Austen.......................................Europe
# Jane_Fonda........................................North America
# Jean-Jacques_Rousseau.............................Europe
# Jerry_Fodor.......................................North America
# Jesse_Owens.......................................North America
# Jesus.............................................Europe
# Jimmy_Carter......................................North America
# Jimmy_Wales.......................................North America
# Joan_of_Arc.......................................Europe
# Jocelin...........................................Europe
# Joel_Brand........................................Europe
# Johann_Pachelbel..................................Europe
# Johann_Sebastian_Bach.............................Europe
# Johann_Wolfgang_Goethe............................Europe
# Johannes_Gutenberg................................Europe
# Johannes_Kepler...................................Europe
# Johannes_Ockeghem.................................Europe
# John_A.T._Robinson................................Europe
# John_Adams........................................North America
# John_Cabot........................................Europe
# John_Calvin.......................................Europe
# John_Constable....................................Europe
# John_Dee..........................................Europe
# John_F._Kennedy...................................North America
# John_Flamsteed....................................Europe
# John_Henninger_Reagan.............................North America
# John_Howard.......................................Australia
# John_Locke........................................Europe
# John_Logie_Baird..................................Europe
# John_Marshall.....................................North America
# John_McEnroe......................................North America
# John_Millington_Synge.............................Europe
# John_Milton.......................................Europe
# John_Pershing.....................................North America
# John_Seigenthaler%2C_Sr...........................North America
# John_Sentamu......................................Europe
# John_Tyler........................................North America
# John_Vanbrugh.....................................Europe
# John_W._Campbell..................................North America
# John_W._Johnston..................................North America
# John_of_England...................................Europe
# John_von_Neumann..................................Europe
# Johnny_Appleseed..................................North America
# Jonah_Lomu........................................Australia
# Jonathan_Wild.....................................Europe
# Jorge_Luis_Borges.................................South America
# Joseph_Haydn......................................Europe
# Joseph_Stalin.....................................Europe
# Juan_Sebasti%C3%A1n_Elcano........................Europe
# Julius_Caesar.....................................Europe
# Karl_Benz.........................................Europe
# Karl_Marx.........................................Europe
# Karl_Popper.......................................Europe
# Keira_Knightley...................................Europe
# Kevin_Spacey......................................North America
# Khan_Wali_Khan....................................Asia
# Kofi_Annan........................................Africa
# Konrad_Lorenz.....................................Europe
# Kurt_Cobain.......................................North America
# Kylie_Minogue.....................................Australia
# L._S._Lowry.......................................Europe
# Lance_Armstrong...................................North America
# Laozi.............................................Unknown
# Laurence_Olivier..................................Europe
# Laurent_Fignon....................................Europe
# Leif_Ericson......................................Europe
# Leo_Tolstoy.......................................Europe
# Leon_Trotsky......................................Europe
# Leonardo_da_Vinci.................................Europe
# Leonhard_Euler....................................Europe
# Linus_Pauling.....................................North America
# Linus_Torvalds....................................Europe
# List_of_French_monarchs...........................Europe
# List_of_monarchs_in_the_British_Isles.............Europe
# List_of_popes.....................................Europe
# Llywelyn_the_Great................................Europe
# Lope_de_Barrientos................................Europe
# Lottie_Dod........................................Europe
# Louis_Armstrong...................................North America
# Louis_Freeh.......................................North America
# Louis_Jordan......................................North America
# Louis_Pasteur.....................................Europe
# Louis_XIV_of_France...............................Europe
# Lucy%2C_Lady_Duff-Gordon..........................Europe
# Ludwig_Wittgenstein...............................Europe
# Ludwig_van_Beethoven..............................Europe
# Lyndon_B._Johnson.................................North America
# Macbeth_of_Scotland...............................Europe
# Mahatma_Gandhi....................................Asia
# Mahmoud_Abbas.....................................Middle East
# Malcolm_X.........................................North America
# Manuel_I_Komnenos.................................Europe
# Mao_Zedong........................................Asia
# Marc_Pugh.........................................Europe
# Marcel_Lefebvre...................................Middle East
# Marcel_Proust.....................................Europe
# Marco_Polo........................................Asia
# Marcus_Allen......................................North America
# Margaret_Sanger...................................North America
# Margaret_Thatcher.................................Europe
# Marie_Curie.......................................Europe
# Mark_Antony.......................................Europe
# Mark_Twain........................................North America
# Mark_Webber.......................................Australia
# Martin_Luther.....................................Europe
# Martin_Luther_King%2C_Jr..........................North America
# Martin_Van_Buren..................................North America
# Martina_Navratilova...............................North America
# Marvin_Gaye.......................................North America
# Mary_II_of_England................................Europe
# Mary_I_of_England.................................Europe
# Mary_I_of_Scotland................................Europe
# Mary_Kingsley.....................................Europe
# Mary_Somerville...................................Europe
# Matsuo_Bash%C5%8D.................................Asia
# Matthew_Brettingham...............................Europe
# Max_Planck........................................Europe
# Max_Weber.........................................Europe
# Michael_Faraday...................................Europe
# Michael_Jordan....................................North America
# Michael_Ramsey....................................Europe
# Michael_Woodruff..................................Europe
# Michelangelo......................................Europe
# Mickey_Mantle.....................................North America
# Miguel_de_Cervantes...............................Europe
# Mikhail_Gorbachev.................................Europe
# Miles_Davis.......................................Europe
# Millard_Fillmore..................................North America
# Miranda_Otto......................................Australia
# Mother_Teresa.....................................Middle East
# Muhammad..........................................Middle East
# Muhammad_Ali......................................North America
# Muhammad_Ali_Jinnah...............................Asia
# Muhammad_Iqbal....................................Europe
# Muhammad_ibn_Musa_al-Khwarizmi....................Middle East
# Nadia_Com%C4%83neci...............................Europe
# Napoleon_I_of_France..............................Europe
# Natalie_Portman...................................Middle East
# Neil_Armstrong....................................North America
# Neil_Young........................................North America
# Nelson_Mandela....................................Africa
# Niccol%C3%B2_Machiavelli..........................Europe
# Niccol%C3%B2_Paganini.............................Europe
# Nicolaus_Copernicus...............................Europe
# Niels_Bohr........................................Europe
# Nikola_Tesla......................................North America
# Nikolai_Rimsky-Korsakov...........................Europe
# Norman_Borlaug....................................North America
# Nostradamus.......................................Europe
# Olaudah_Equiano...................................Africa
# Oliver_Cromwell...................................Europe
# Ollanta_Humala....................................South America
# Osama_bin_Laden...................................Middle East
# Otto_von_Bismarck.................................Europe
# Pablo_Picasso.....................................Europe
# Pat_Cash..........................................Australia
# Paul_C%C3%A9zanne.................................Europe
# Paul_Dirac........................................Europe
# Paul_Kane.........................................North America
# Paul_McCartney....................................Europe
# Paul_of_Tarsus....................................Europe
# Pedro_del_Valle...................................South America
# Pel%C3%A9.........................................South America
# Penda_of_Mercia...................................Europe
# Pericles..........................................Europe
# Pete_Sampras......................................North America
# Peter_I_of_Russia.................................Europe
# Peter_Paul_Rubens.................................Europe
# Philip_II_of_Spain................................Europe
# Plato.............................................Europe
# Pope_Benedict_XVI.................................Europe
# Pope_John_Paul_II.................................Europe
# Pope_Pius_XII.....................................Europe
# Ptolemy...........................................Europe
# Pyotr_Ilyich_Tchaikovsky..........................Europe
# Pythagoras........................................Europe
# Qin_Shi_Huang.....................................Asia
# Rabindranath_Tagore...............................Asia
# Ralph_Nader.......................................North America
# Raphael...........................................Europe
# Rebecca_Helferich_Clarke..........................Europe
# Rembrandt.........................................Europe
# Ren%C3%A9_Descartes...............................Europe
# Reza_Shah.........................................Middle East
# Richard_Feynman...................................North America
# Richard_Francis_Burton............................Europe
# Richard_III_of_England............................Europe
# Richard_II_of_England.............................Europe
# Richard_I_of_England..............................Europe
# Richard_Nixon.....................................North America
# Richard_Stallman..................................South America
# Richard_Wagner....................................Europe
# Roald_Amundsen....................................Europe
# Robert_Boyle......................................Europe
# Robert_Gascoyne-Cecil%2C_3rd_Marquess_of_SalisburyEurope
# Robert_Oppenheimer................................North America
# Robert_Owen.......................................Europe
# Robert_Schumann...................................Europe
# Roman_Vishniac....................................Europe
# Romulus_Augustus..................................Europe
# Ronald_Reagan.....................................North America
# Rosa_Parks........................................North America
# Rowan_Williams....................................Europe
# Rudolf_Vrba.......................................Europe
# Rudyard_Kipling...................................Asia
# Rutherford_B._Hayes...............................North America
# S%C3%B8ren_Kierkegaard............................Europe
# S._A._Andr%C3%A9e%27s_Arctic_balloon_expedition_of_1897Europe
# Saladin...........................................Middle East
# Salvador_Dal%C3%AD................................Europe
# Samantha_Smith....................................North America
# Samuel_Beckett....................................Europe
# Samuel_Taylor_Coleridge...........................Europe
# Sandy_Koufax......................................North America
# Sardar_Vallabhbhai_Patel..........................Asia
# Sasha_%28DJ%29....................................Europe
# Sean_Connery......................................Europe
# Selena............................................North America
# Shaka.............................................Africa
# Sharon_Tate.......................................North America
# Sheikh_Mujibur_Rahman.............................Asia
# Sigmund_Freud.....................................Europe
# Sim%C3%B3n_Bol%C3%ADvar...........................South America
# Sitting_Bull......................................North America
# Socrates..........................................Europe
# Stanis%C5%82aw_Koniecpolski.......................Europe
# Stanis%C5%82aw_Lem................................Europe
# Stanley_Baldwin...................................Europe
# Stefan_Edberg.....................................Europe
# Stephen_Harper....................................North America
# Stephen_Hawking...................................Europe
# Stephen_Jay_Gould.................................North America
# Stephen_Trigg.....................................North America
# Steve_Davis.......................................Europe
# Suleiman_the_Magnificent..........................Middle East
# Sun_Yat-sen.......................................Asia
# Sydney_Newman.....................................North America
# T._S._Eliot.......................................Europe
# Tenzin_Gyatso%2C_14th_Dalai_Lama..................Asia
# Tenzing_Norgay....................................Asia
# Theodore_Roosevelt................................North America
# Thomas_Aquinas....................................Europe
# Thomas_Becket.....................................Europe
# Thomas_Cranmer....................................Europe
# Thomas_Edison.....................................North America
# Thomas_Gainsborough...............................Europe
# Thomas_Hobbes.....................................Europe
# Thomas_Jefferson..................................North America
# Thomas_Malthus....................................Europe
# Thomas_More.......................................Europe
# Thomas_Pynchon....................................North America
# Thomas_Samuel_Kuhn................................Europe
# Thrasybulus.......................................Europe
# Tiger_Woods.......................................North America
# Tim_Berners-Lee...................................Europe
# Tim_Henman........................................Europe
# Timur.............................................Middle East
# Tiridates_I_of_Armenia............................Europe
# Tony_Blair........................................Europe
# Tupac_Shakur......................................North America
# Tycho_Brahe.......................................Europe
# Ulysses_S._Grant..................................North America
# Vasco_da_Gama.....................................Europe
# Vernon_Kell.......................................Europe
# Victor_Hugo.......................................Europe
# Victoria_of_the_United_Kingdom....................Europe
# Vincent_van_Gogh..................................Europe
# Virgil............................................Europe
# Vitus_Bering......................................Europe
# Vivien_Leigh......................................Europe
# Vladimir_Lenin....................................Europe
# Voltaire..........................................Europe
# W._Mark_Felt......................................North America
# Walt_Disney.......................................North America
# Walt_Whitman......................................North America
# Walter_Raleigh....................................Europe
# Walter_Scott......................................Europe
# Ward_Cunningham...................................North America
# Warren_G._Harding.................................North America
# Wayne_Rooney......................................Europe
# Wernher_von_Braun.................................Europe
# Willem_Barents....................................Europe
# William_Butler_Yeats..............................Europe
# William_Edington..................................Europe
# William_Ewart_Gladstone...........................Europe
# William_Gilbert...................................Europe
# William_Harvey....................................Europe
# William_Henry_Harrison............................North America
# William_Hogarth...................................Europe
# William_Howard_Taft...............................North America
# William_III_of_England............................Europe
# William_II_of_England.............................Europe
# William_IV_of_the_United_Kingdom..................Europe
# William_I_of_England..............................Europe
# William_Mahone....................................North America
# William_McKinley..................................North America
# William_N._Page...................................North America
# William_Pitt_the_Younger..........................Europe
# William_Renshaw...................................Europe
# William_Shakespeare...............................Europe
# William_Tecumseh_Sherman..........................North America
# William_Thomson%2C_1st_Baron_Kelvin...............Europe
# William_Wilberforce...............................Europe
# William_and_Mary..................................Europe
# William_the_Silent................................Europe
# Winfield_Scott_Hancock............................North America
# Winston_Churchill.................................Europe
# Witold_Pilecki....................................Europe
# Wolfgang_Amadeus_Mozart...........................Europe
# Woodrow_Wilson....................................North America
# Wright_brothers...................................North America
# Wyndham_Robertson.................................North America
# Yagan.............................................Europe
# Yuri_Gagarin......................................Europe
# Yuri_Knorosov.....................................Europe
# Zachary_Taylor....................................North America
# Zara_Yaqob........................................Africa
# Zhang_Qian........................................Asia
# Zheng_He..........................................Asia
# Ziad_Jarrah.......................................Middle East
# Zionism...........................................Middle East
# Zoroaster.........................................Middle East

# %% [markdown]
# # Article/Page rank
#
# We have computed page rank for each article, which could give us interesting insight on articles or be used as feature in observation study matching.

# %%
print(f"{'Article' : <37} Page Rank")
for index in range(10):
    print(f"{df_page_rank.iloc[index].Article :.<40}{df_page_rank.iloc[index].PageRank :.5f}")
# Out:
# Article                               Page Rank
# United_States...........................0.01426
# United_Kingdom..........................0.00768
# Scientific_classification...............0.00721
# Europe..................................0.00704
# England.................................0.00682
# France..................................0.00670
# Animal..................................0.00659
# World_War_II............................0.00554
# English_language........................0.00496
# London..................................0.00496
